# %%
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Import the moovies dataset

# %% [markdown]
# # https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset

# %%
df = pd.read_csv("movie_metadata.csv")
pd.set_option('display.max_column', 28)
df.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %% [markdown]
# ### 2. Use crosstabs to show the number of moovies per country

# %%
pd.crosstab(df.country, columns="number_of_movies", values=df.movie_title, aggfunc='count')
# Out:
# col_0                 number_of_movies
# country
# Afghanistan                          1
# Argentina                            4
# Aruba                                1
# Australia                           55
# Bahamas                              1
# ...                                ...
# Turkey                               1
# UK                                 448
# USA                               3807
# United Arab Emirates                 1
# West Germany                         3
#
# [65 rows x 1 columns]

# %% [markdown]
# ### 3. Create a crosstab to show the number of films per director and genre splitted by country

# %%
pd.crosstab([df.director_name, df.genres], [df.country], dropna=True)
# Out:
# country                                                    Afghanistan  \
# director_name      genres
# A. Raven Cruz      Action|Adventure|Comedy|Fantasy|Sci-Fi            0
# Aaron Hann         Drama|Horror|Mystery|Sci-Fi|Thriller              0
# Aaron Schneider    Drama|Mystery                                     0
# Aaron Seltzer      Comedy|Romance                                    0
# Abel Ferrara       Crime|Drama                                       0
# ...                                                                ...
# Zoran Lisinac      Comedy|Music|Romance                              0
# Álex de la Iglesia Crime|Mystery|Thriller                            0
# Émile Gaudreault   Comedy|Drama                                      0
# Éric Tessier       Action|Drama|Horror|Thriller                      0
# Étienne Faure      Drama|Musical|Romance                             0
#
# country                                                    Argentina  Aruba  \
# ...

# %% [markdown]
# ### 4. Average duration of filmes grouped by color

# %%
# HOW TO AGGREGATE ?
pd.crosstab(df.color, columns="average_duration", values=df.duration, aggfunc=np.mean)

# SOLUTION WITH GROUPBY
#df.groupby("color")["duration"].mean()
# Out:
# col_0             average_duration
# color
#  Black and White        112.253589
# Color                   107.042908

# %% [markdown]
# ### 5. Average number of likes per director (assuming that total film's likes are counted as a sum of actor's likes)

# %%
# NOT SOLVED
pd.crosstab(df.director_name, columns=["actor_1_likes"], values=df.actor_1_facebook_likes, aggfunc=np.sum)
pd.crosstab(df.director_name, columns=["actor_2_likes"], values=df.actor_2_facebook_likes, aggfunc=np.sum)
# Out:
# col_0               actor_2_likes
# director_name
# A. Raven Cruz               361.0
# Aaron Hann                  152.0
# Aaron Schneider            3000.0
# Aaron Seltzer               869.0
# Abel Ferrara                787.0
# ...                           ...
# Zoran Lisinac               297.0
# Álex de la Iglesia          161.0
# Émile Gaudreault            210.0
# Éric Tessier                 16.0
# Étienne Faure                 0.0
#
# [2398 rows x 1 columns]
