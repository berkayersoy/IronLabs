# %%
import pandas as pd

# %%
# Data Preparation

headers = "TransactionID | ClientID | Profession | Bank_dep | Risk | Number of credits | Revenue"
headers = headers.split(" | ")

row_1 = "1 | 231 | Self-employed | 009 | high | 2 | 30200"
row_2 = "2 | 765 | students | 005 | high | 3 | 12700"
row_3 = "3 | 453 | Horeca | 007 | medium | 5 | 89400"
row_4 = "4 | 231 | Self-employed | 009 | high | 2 | 30200"
row_5 = "5 | 892 | finance | 003 | low | 3 | 740000"

row_1 = row_1.split(" | ")
row_2 = row_2.split(" | ")
row_3 = row_3.split(" | ")
row_4 = row_4.split(" | ")
row_5 = row_5.split(" | ")

data = pd.DataFrame([row_1,row_2,row_3,row_4,row_5], columns=headers)

data
# Out:
#   TransactionID ClientID     Profession Bank_dep    Risk Number of credits  \
# 0             1      231  Self-employed      009    high                 2
# 1             2      765       students      005    high                 3
# 2             3      453         Horeca      007  medium                 5
# 3             4      231  Self-employed      009    high                 2
# 4             5      892        finance      003     low                 3
#
#   Revenue
# 0   30200
# 1   12700
# 2   89400
# 3   30200
# 4  740000

# %%
# Dummy Encoder
pd.get_dummies(data)
# Out:
#    TransactionID_1  TransactionID_2  TransactionID_3  TransactionID_4  \
# 0                1                0                0                0
# 1                0                1                0                0
# 2                0                0                1                0
# 3                0                0                0                1
# 4                0                0                0                0
#
#    TransactionID_5  ClientID_231  ClientID_453  ClientID_765  ClientID_892  \
# 0                0             1             0             0             0
# 1                0             0             0             1             0
# 2                0             0             1             0             0
# 3                0             1             0             0             0
# 4                1             0             0             0             1
#
#    Profession_Horeca  ...  Risk_high  Risk_low  Risk_medium  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# creating instance of labelencoder
label_encoder = LabelEncoder()

data["Profession_Label_Encoded"] = LabelEncoder().fit_transform(data["Profession"])
data
# Out:
#   TransactionID ClientID     Profession Bank_dep    Risk Number of credits  \
# 0             1      231  Self-employed      009    high                 2
# 1             2      765       students      005    high                 3
# 2             3      453         Horeca      007  medium                 5
# 3             4      231  Self-employed      009    high                 2
# 4             5      892        finance      003     low                 3
#
#   Revenue  Profession_Label_Encoded
# 0   30200                         1
# 1   12700                         3
# 2   89400                         0
# 3   30200                         1
# 4  740000                         2

# %%
from sklearn.preprocessing import OrdinalEncoder

# creating an instance of ordinal encoder
ordinal_encoder = OrdinalEncoder()

#data["Risk_Ordinal_Encoded"] = ordinal_encoder.fit_transform(data["Risk"])
#data

X = [['009','high'],['005','high'],['007','medium'],['009','high'],['003','low']]

ordinal_encoder.fit_transform(X)
# Out:
# array([[3., 0.],
#        [1., 0.],
#        [2., 2.],
#        [3., 0.],
#        [0., 1.]])
