# %%
import pandas as pd

# %% [markdown]
# # First I'll read the data and check for errors/missing data/typo's/datatypes everything for data cleaning.

# %%
df = pd.read_excel("example_data_cleaning.xlsx")
df
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession  Department  \
# 0               4     34985  1923.000000     5670      manager          78
# 1              16     34997  1923.000000  2399090    developer          78
# 2              25     35006  1923.000000    33050           HR          78
# 3              12     34993  1939.142857    23430    professor          78
# 4              21     35002  1939.142857    16770      manager          78
# 5              11     34992  1943.857143    21210   researcher          78
# 6              20     35001  1943.857143    14550      student          78
# 7               3     34984  1945.000000     3450      student          78
# 8              19     35000  1948.571429    12330       barmen          78
# 9               9     34990  1953.285714    16770      Manager          78
# 10              8     34989  1958.000000    14550           HR          78
# ...

# %% [markdown]
# # I can see there are some typo's in Profession. Some datatype errors in BirthYear for example. I will fix those and also check how many NAN's in the dataframe.

# %%
null_columns = df.isnull().sum()
null_columns
# Out:
# TransactionID    0
# ClientID         0
# BirthYear        2
# Amount           0
# Profession       2
# Department       0
# Risk             0
# dtype: int64

# %% [markdown]
# # There are only 2 NAN's I will fill them.

# %%
df['BirthYear']= df['BirthYear'].fillna(0)
df['BirthYear'] = df['BirthYear'].astype('int64')
df
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 0               4     34985       1923     5670      manager          78
# 1              16     34997       1923  2399090    developer          78
# 2              25     35006       1923    33050           HR          78
# 3              12     34993       1939    23430    professor          78
# 4              21     35002       1939    16770      manager          78
# 5              11     34992       1943    21210   researcher          78
# 6              20     35001       1943    14550      student          78
# 7               3     34984       1945     3450      student          78
# 8              19     35000       1948    12330       barmen          78
# 9               9     34990       1953    16770      Manager          78
# 10              8     34989       1958    14550           HR          78
# 11              6     34987       1967    10110      Manager          78
# ...

# %%
df['Profession']= df['Profession'].fillna("Not Specified")
df
# Out:
#     TransactionID  ClientID  BirthYear   Amount     Profession  Department  \
# 0               4     34985       1923     5670        manager          78
# 1              16     34997       1923  2399090      developer          78
# 2              25     35006       1923    33050             HR          78
# 3              12     34993       1939    23430      professor          78
# 4              21     35002       1939    16770        manager          78
# 5              11     34992       1943    21210     researcher          78
# 6              20     35001       1943    14550        student          78
# 7               3     34984       1945     3450        student          78
# 8              19     35000       1948    12330         barmen          78
# 9               9     34990       1953    16770        Manager          78
# 10              8     34989       1958    14550             HR          78
# ...

# %% [markdown]
# # Fixing some typo's.

# %%
df['Profession'] = df['Profession'].str.replace('etudient', 'Student')

# Capitalize the values in the profession column.
df['Profession'] = df['Profession'].str.capitalize()
df.head()
# Out:
#    TransactionID  ClientID  BirthYear   Amount Profession  Department  Risk
# 0              4     34985       1923     5670    Manager          78   Low
# 1             16     34997       1923  2399090  Developer          78  High
# 2             25     35006       1923    33050         Hr          78  High
# 3             12     34993       1939    23430  Professor          78   Low
# 4             21     35002       1939    16770    Manager          78   Low

# %%
len(df)
# Out:
# 30

# %% [markdown]
# # Dropping duplicates

# %%
# Removing duplicates
df = df.drop_duplicates()
len(df)
# No duplicates found.
# Out:
# 30

# %% [markdown]
# # Encoding

# %%
df.head()
# Out:
#    TransactionID  ClientID  BirthYear   Amount  Profession  Department  Risk
# 0              4     34985       1923     5670           6          78     1
# 1             16     34997       1923  2399090           2          78     0
# 2             25     35006       1923    33050           5          78     0
# 3             12     34993       1939    23430           8          78     1
# 4             21     35002       1939    16770           6          78     1

# %%
# Categorical boolean mask
categorical_feature_mask = df.dtypes==object
# Filtering categorical columns by using mask
categorical_cols = df.columns[categorical_feature_mask].tolist()

# %%
# Importing LabelEncoder
from sklearn.preprocessing import LabelEncoder
# Instance of the labelencoder.
le = LabelEncoder()

# %%
# apply le on categorical feature columns
df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))
df[categorical_cols].head(10)
# Out:
#    Profession  Risk
# 0           6     1
# 1           2     0
# 2           5     0
# 3           8     1
# 4           6     1
# 5           9     2
# 6          11     2
# 7          11     2
# 8           0     0
# 9           6     2
