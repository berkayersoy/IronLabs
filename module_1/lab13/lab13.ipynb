# %%
import tweepy
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAADW8lQEAAAAAkgqcrVBPhHgVE9YOAjV2uRYxCmI%3D5fpmAMmrhinBPNR2fyUJdDYKoHqeV2jgm8ZSItwAOoGWXwbREi')
#Replace with your own search query
query = 'Ironhack'
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)
for tweet in tweets.data:
   print(tweet.text)
   if len(tweet.context_annotations) > 0:
       print(tweet.context_annotations)

# %%
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
                                    user_fields=['profile_image_url'], expansions='author_id', max_results=100)
# Get users list from the includes object
users = {u["id"]: u for u in tweets.includes['users']}
for tweet in tweets.data:
    if users[tweet.author_id]:
        user = users[tweet.author_id]
        print(user.profile_image_url)

# %%
query = 'covid -is:retweet has:media lang:en'
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
                                media_fields=['preview_image_url'], expansions='attachments.media_keys', max_results=100)
# Get list of media from the includes object
media = {m["media_key"]: m for m in tweets.includes['media']}
for tweet in tweets.data:
    attachments = tweet.data['attachments']
    media_keys = attachments['media_keys']
    print(tweet.text)
    if media[media_keys[0]].preview_image_url:
         print(media[media_keys[0]].preview_image_url)
         print("_____________________________________________________________________________________________________________________________________________________________________________")

# %%
import requests

response = requests.get("https://xkcd.com")
response.headers["Expires"] # checking for header "Expires"
response.text # provides all html text
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '2685', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Wed, 25 Jan 2023 19:57:29 GMT', 'ETag': 'W/"63d189a9-1ba0"', 'Expires': 'Wed, 25 Jan 2023 20:03:06 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Thu, 26 Jan 2023 08:35:00 GMT', 'Age': '29', 'X-Served-By': 'cache-dfw-kdfw8210121-DFW, cache-cdg20767-CDG', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '76, 1', 'X-Timer': 'S1674722101.628132,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
response2 = requests.get("https://imgs.xkcd.com/comics/optimal_bowling.png")

with open('comic.png', 'wb') as f:
    f.write(response2.content)

# %%
# Challenge 2 point 3
url="https://httpbin.org/post"
params3={'things':2,'total':25}
response3=requests.post(url, params=params3)
response3.content
# Out:
# b'{\n  "args": {\n    "things": "2", \n    "total": "25"\n  }, \n  "data": "", \n  "files": {}, \n  "form": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "0", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.28.2", \n    "X-Amzn-Trace-Id": "Root=1-63d23b3a-7c1c44153ae3509a5dd1d52d"\n  }, \n  "json": null, \n  "origin": "185.146.221.98", \n  "url": "https://httpbin.org/post?things=2&total=25"\n}\n'

# %%
# Challenge 2 point 4
params_username_password={'username':"berkay",'password':"abc123"}
response4=requests.post(url, data=params_username_password)
response4.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'password': 'abc123', 'username': 'berkay'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '31',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.28.2',
#   'X-Amzn-Trace-Id': 'Root=1-63d23b8e-4c4d4f482733f8687f29c311'},
#  'json': None,
#  'origin': '185.146.221.98',
#  'url': 'https://httpbin.org/post'}

# %%
# Challenge 2 point 5
response_dictionary = response4.json()
response_dictionary
response_dictionary['form']
# Out:
# {'password': 'abc123', 'username': 'berkay'}

# %%
# Challenge 3
response5 = requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
search = response5.json()
search['items']

repo_files_names = [item["name"] for item in search["items"]]
repo_files_names.sort()
repo_files_names

#Take name and url from search["items"]
repo_files_urls = {item["name"]: item["url"] for item in search["items"]}
repo_files_urls

repo_files = [requests.get(repo_files_urls[repo_filename]) for repo_filename in repo_files_names]
repo_files

repo_files_content = [file.json()["content"] for file in repo_files]
repo_files_content

import base64
message = [base64.b64decode(b64message).decode('ascii') for b64message in repo_files_content]
message
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 17
#      14 repo_files = [requests.get(repo_files_urls[repo_filename]) for repo_filename in repo_files_names]
#      15 repo_files
# ---> 17 repo_files_content = [file.json()["content"] for file in repo_files]
#      18 repo_files_content
#      20 import base64
#
# Cell In[16], line 17, in <listcomp>(.0)
#      14 repo_files = [requests.get(repo_files_urls[repo_filename]) for repo_filename in repo_files_names]
#      15 repo_files
# ---> 17 repo_files_content = [file.json()["content"] for file in repo_files]
#      18 repo_files_content
#      20 import base64
#
# KeyError: 'content'

# %%
#Searching for my commits in my IronLabs repository.
test=requests.get('https://api.github.com/search/commits?q=berkayersoy/IronLabs')
test.json()
# Out:
# {'total_count': 1,
#  'incomplete_results': False,
#  'items': [{'url': 'https://api.github.com/repos/berkayersoy/IronLabs/commits/e966dd8259b08642133b28c1eccf264ecf54f7eb',
#    'sha': 'e966dd8259b08642133b28c1eccf264ecf54f7eb',
#    'node_id': 'MDY6Q29tbWl0NTg5NjY0ODE1OmU5NjZkZDgyNTliMDg2NDIxMzNiMjhjMWVjY2YyNjRlY2Y1NGY3ZWI=',
#    'html_url': 'https://github.com/berkayersoy/IronLabs/commit/e966dd8259b08642133b28c1eccf264ecf54f7eb',
#    'comments_url': 'https://api.github.com/repos/berkayersoy/IronLabs/commits/e966dd8259b08642133b28c1eccf264ecf54f7eb/comments',
#    'commit': {'url': 'https://api.github.com/repos/berkayersoy/IronLabs/git/commits/e966dd8259b08642133b28c1eccf264ecf54f7eb',
#     'author': {'date': '2023-01-17T13:16:10.000+01:00',
#      'name': 'berkayersoy',
#      'email': 'berkayersoy17@gmail.com'},
#     'committer': {'date': '2023-01-17T13:16:10.000+01:00',
#      'name': 'berkayersoy',
#      'email': 'berkayersoy17@gmail.com'},
# ...

# %%
#List repositories for a user.
test2=requests.get('https://api.github.com/users/berkayersoy/repos')
test2.json()
# Out:
# [{'id': 590187824,
#   'node_id': 'R_kgDOIy2NMA',
#   'name': 'DAFT_0116',
#   'full_name': 'berkayersoy/DAFT_0116',
#   'private': False,
#   'owner': {'login': 'berkayersoy',
#    'id': 44724944,
#    'node_id': 'MDQ6VXNlcjQ0NzI0OTQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44724944?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/berkayersoy',
#    'html_url': 'https://github.com/berkayersoy',
#    'followers_url': 'https://api.github.com/users/berkayersoy/followers',
#    'following_url': 'https://api.github.com/users/berkayersoy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/berkayersoy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/berkayersoy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/berkayersoy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/berkayersoy/orgs',
# ...
